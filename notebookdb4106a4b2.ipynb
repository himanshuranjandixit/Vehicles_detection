# %%
# !pip install -q ultralytics roboflow python-dotenv python-magic opencv-python-headless==4.8.0.74
# Out:
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 34.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="bT91Ex99xetx09SIUkRb")
project = rf.workspace("himanshu-dixit-f6ecv").project("humans-and-vechicles-cwupj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dependency ultralytics==8.0.196 is required but found version=8.3.166, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Humans-and-Vechicles-1 in yolov8:: 100%|██████████| 12028/12028 [00:01<00:00, 7498.85it/s]

# %%
from ultralytics import YOLO
model = YOLO("yolov8s.yaml")

# %%
import yaml

yaml_path = "/kaggle/working/Humans-and-Vechicles-1/data.yaml"

with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# Fix the paths
base = "/kaggle/working/Humans-and-Vechicles-1"
data['train'] = f"{base}/train/images"
data['val'] = f"{base}/valid/images"
data['test'] = f"{base}/test/images"

# Save the updated yaml
with open(yaml_path, 'w') as f:
    yaml.dump(data, f)

print("✅ Fixed data.yaml paths.")
# Out:
# ✅ Fixed data.yaml paths.

# %%
model.train(data= '/kaggle/working/Humans-and-Vechicles-1/data.yaml',
            epochs=10,
            imgsz=640,
            batch=16
)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/kaggle/working/runs/detect/train3/weights/best.pt")

model.train(
    data='/kaggle/working/Humans-and-Vechicles-1/data.yaml',
    epochs=10,  # train for more than 10 total
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/kaggle/working/runs/detect/train6/weights/last.pt")

model.train(
    data='/kaggle/working/Humans-and-Vechicles-1/data.yaml',
    epochs=10,  # train for more than 10 total
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/kaggle/working/runs/detect/train7/weights/last.pt")

model.train(
    data='/kaggle/working/Humans-and-Vechicles-1/data.yaml',
    epochs=10,  # train for more than 10 total
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
